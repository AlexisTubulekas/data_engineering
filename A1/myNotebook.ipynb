# %%
! cowsay yello
# Out:
#  _______
# < yello >
#  -------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
from IPython.lib import passwd
password = passwd("secret")
password
# Out:
# 'sha1:ed6f8856bfc7:d57f4e9aa8ccc5a957eea2b45d1e4d675450aba0'
